# %%
import pandas as pd

# %%
df = pd.read_csv("pirates.csv")

# %%
column_type = df["parrots"].dtype
print(column_type)
# Out:
# object

# %%
df.head()
# Out:
#    id     sex   age  height  weight headband college  tattoos  tchests  \
# 0   1    male  28.0  173.11    70.5      yes   JSSFP        9        0
# 1   2    male  31.0  209.25   105.6      yes   JSSFP        9       11
# 2   3    male  26.0  169.95    77.1      yes    CCCC       10       10
# 3   4  female  31.0  144.29    58.5       no   JSSFP        2        0
# 4   5  female  41.0  157.85    58.4      yes   JSSFP        9        6
#
#   parrots favorite.pirate sword.type  eyepatch  sword.time  beard.length  \
# 0       0    Jack Sparrow    cutlass         1        0.58            16
# 1       0    Jack Sparrow    cutlass         0        1.11            21
# 2       1    Jack Sparrow    cutlass         1        1.44            19
# 3       2    Jack Sparrow   scimitar         1       36.11             2
# 4       4            Hook    cutlass         1        0.11             0
#
#         fav.pixar  grogg
# 0  Monsters, Inc.     11
# 1          WALL-E      9
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1000 non-null   int64
#  1   sex              1000 non-null   object
#  2   age              999 non-null    float64
#  3   height           1000 non-null   float64
#  4   weight           1000 non-null   float64
#  5   headband         999 non-null    object
#  6   college          1000 non-null   object
#  7   tattoos          1000 non-null   int64
#  8   tchests          1000 non-null   int64
#  9   parrots          1000 non-null   object
#  10  favorite.pirate  999 non-null    object
#  11  sword.type       1000 non-null   object
#  12  eyepatch         1000 non-null   int64
#  13  sword.time       999 non-null    float64
#  14  beard.length     1000 non-null   int64
#  15  fav.pixar        1000 non-null   object
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        id     sex   age  height  weight headband college  tattoos  tchests  \
# 0       1    male  28.0  173.11    70.5      yes   JSSFP        9        0
# 1       2    male  31.0  209.25   105.6      yes   JSSFP        9       11
# 2       3    male  26.0  169.95    77.1      yes    CCCC       10       10
# 3       4  female  31.0  144.29    58.5       no   JSSFP        2        0
# 4       5  female  41.0  157.85    58.4      yes   JSSFP        9        6
# ..    ...     ...   ...     ...     ...      ...     ...      ...      ...
# 995   996    male  26.0  178.83    70.8      yes    CCCC       14       11
# 996   997  female  34.0  157.20    53.6      yes   JSSFP       13       48
# 997   998    male  36.0  175.74    72.4      yes   JSSFP        9       95
# 998   999    male  30.0  175.24    70.2      yes   JSSFP        9        6
# 999  1000    male  30.0  189.45    84.0      NaN   JSSFP       10       36
#
# ...

# %%
missing_data = df.isna().any()

# %%
for column_name, has_missing in missing_data.iteritems():
    if has_missing:
        missing_rows = df[df[column_name].isna()].index.tolist()
        print(f"Missing values in column '{column_name}':")
        for row_number in missing_rows:
            print(f"Row {row_number}: {df.at[row_number, column_name]}")
# Out:
# Missing values in column 'age':
# Row 33: nan
# Missing values in column 'headband':
# Row 999: nan
# Missing values in column 'favorite.pirate':
# Row 634: nan
# Missing values in column 'sword.time':
# Row 136: nan
# /var/folders/39/crqhrg617cvg177_1n2_rsw40000gn/T/ipykernel_4720/2173272415.py:1: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column_name, has_missing in missing_data.iteritems():

# %%
df["age"].fillna(df["agez].mean(), inplace=True)

# %%
df.dropna(inplace=True) 
df.reset_index(inplace=True)

# %%
df["age"].mean()
# Out:
# 27.3714859437751

# %%
df.loc[33,"age"]= df["age"].mean()

# %%
df.head(35)
# Out:
#       id     sex   age  height  weight headband college  tattoos  tchests  \
# 0    1.0    male  28.0  173.11    70.5      yes   JSSFP      9.0      0.0
# 1    2.0    male  31.0  209.25   105.6      yes   JSSFP      9.0     11.0
# 2    3.0    male  26.0  169.95    77.1      yes    CCCC     10.0     10.0
# 3    4.0  female  31.0  144.29    58.5       no   JSSFP      2.0      0.0
# 4    5.0  female  41.0  157.85    58.4      yes   JSSFP      9.0      6.0
# 5    6.0    male  26.0  190.20    85.4      yes    CCCC      7.0     19.0
# 6    7.0  female  31.0  158.05    59.6      yes   JSSFP      9.0      1.0
# 7    8.0  female  31.0  172.52    74.5      yes   JSSFP      5.0     13.0
# 8    9.0  female  28.0  164.57    68.7      yes   JSSFP     12.0     37.0
# 9   10.0    male  30.0  183.52    84.7      yes   JSSFP     12.0     69.0
# 10  11.0  female  25.0  162.49    63.5      yes    CCCC     10.0      1.0
# 11  12.0    male  20.0  163.65    70.0      yes    CCCC     14.0      5.0
# ...

# %%
unique_genders = df["sex"].unique()
num_unique_genders = len(unique_genders)
print("unique Genders")
for gender in unique_genders:
    print(gender)
    
print(num_unique_genders)
# Out:
# unique Genders
# male
# female
# other
# 3

# %%
average_age = df["age"].mean()
print(average_age)
# Out:
# 27.3714859437751

# %%
female_age = df[df["sex"]== "female"]["age"].mean()
print(female_age)
# Out:
# 29.932900432900432

# %%
df["weight_pounds"] = df["weight"]* 2.20462

# %%
weight_under100 = df["weight_pounds"]< 100

# %%
percentage_under100 = (weight_under100.sum()/ len(df))*100

# %%
print(percentage_under100)
# Out:
# 0.8032128514056224

# %%
shortest_height = df[df["id"]== "height"]["height"].min()
print(shortest_height)
# Out:
# id                 NaN
# sex                NaN
# age                NaN
# height             NaN
# weight             NaN
# headband           NaN
# college            NaN
# tattoos            NaN
# tchests            NaN
# parrots            NaN
# favorite.pirate    NaN
# sword.type         NaN
# eyepatch           NaN
# sword.time         NaN
# beard.length       NaN
# fav.pixar          NaN
# grogg              NaN
# weight_pounds      NaN
# dtype: object

# %%
idx= df["height"].idxmin()
print(idx)
# Out:
# 37

# %%
idx= df["weight"].idxmax()
print(idx)
# Out:
# 1

# %%
df["fav.pixar"].mode()[0]
# Out:
# 'Inside Out'

# %%
df["eyepatch"].mean()
# Out:
# 0.6576305220883534

# %%
df["eyepatch"].median()
# Out:
# 1.0

# %%
df.loc[35, "parrots"] = 1
idx = 0
for i in df["parrots"]:
    df.loc[idx, "parrots"] = int(i)
    idx = idx +1

# %%
df["parrots"].mean()
# Out:
# 2.819277108433735

# %%
df["parrots"].median()
# Out:
# 2.0

# %%
newRow = pd.read_csv("PirateNewRow.csv")
combined_df = pd.

# %%
newCol = pd.read_csv("PirateNewColumn.csv")

# %%
pirate_df = pd.read_csv("pirates.csv")
PirateNewColumn_df = pd.read_csv("PirateNewColumn.csv")


combined_df = pd.concat([pirate_df, PirateNewColumn_df], ignore_index=True)


combined_df.to_csv('combined_pirates.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1000 non-null   int64
#  1   favorite.sea  1000 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 15.8+ KB

# %%
merged_df = pd.merge(combined_df,newCol, on= 'id',how = 'inner')

# %% [raw]
# merged_df.head(5)
